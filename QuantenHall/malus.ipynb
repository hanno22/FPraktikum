# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
I = 5
phi = np.linspace(0, 2 * np.pi, 1000)
X = I * np.cos(phi)
Y = I * np.sin(phi)

# %%
X_m = np.array([5.15, 0.1, -5.0, 0, 3.6])
Y_m = np.array([0.2, -5.0, 0.0, 5, -3.4])
phi_m = np.array([0, 90, 180, 270, 45])

# %%
fig, ax = plt.subplots()
ax.plot(np.rad2deg(phi), X, label="$sin(\phi)$")
ax.plot(np.rad2deg(phi), -Y, label="$-cos(\phi)$")

ax.scatter(phi_m, X_m, label="X")
ax.scatter(phi_m, Y_m, label="Y")
ax.scatter(phi_m, np.sqrt(np.power(X_m, 2) + np.power(Y_m,2)), label="$\sqrt{X^2 + Y^2}$")
ax.set(ylabel="U/V", xlabel="$\phi/$°")
ax.legend()
fig.savefig("out/phasenlage")
