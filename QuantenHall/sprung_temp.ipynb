# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('data/Super/supra.dat', delimiter='\t', skiprows=26, usecols=[1, 6, 7])

data = data[data[:, 0].argsort()]

T = data[:, 0]
I = data[:, 1]
R = data[:, 2]

# %%
fig, ax = plt.subplots()
ax.scatter(T, R, marker='.')
ax.set(xlim=[8, 11], xlabel='$T / \\mathrm{K}$', ylabel="$R / \\mathrm{\\Omega}$")
ax.grid()
fig.savefig('out/sprung_temp')
