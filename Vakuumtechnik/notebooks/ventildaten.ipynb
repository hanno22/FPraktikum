# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate as interp
import matplotlib

# %%
#data = np.loadtxt("../data/Ventildaten_in.dat", skiprows=1)
#valve_pos = data[:,1]
#flow = data[:,0]
#valv_func  = interp.interp1d(valve_pos, flow, fill_value="extrapolate")
#ns = np.arange(1, 1000)
#data_out = np.savetxt("../data/Ventildaten.dat", np.array([ns, valv_func(ns)]).swapaxes(0,1), fmt= ["%.0f", "%1.4e"], header="ValvePos \t Flow")

data = np.loadtxt("../data/Ventildaten.dat", skiprows=1)
valve_pos = data[:,0]
flow = data[:,1]

# %%
fig, ax = plt.subplots()
ax.set(xscale="log",yscale="log",  xlabel="Gasfluss / (mbar l / s)", ylabel = "Ventilöffnung")
ax.plot(flow, valve_pos)
#ax.plot(valv_func(ns), ns)
#ax.grid()
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8), numticks=12)
ax.xaxis.set_minor_locator(locmin)
ax.xaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
ax.grid(which="minor")
ax.grid(which="major")

fig.savefig('../out/ventildaten.png')
